# %%
# Imports and setup
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.dummy import DummyRegressor
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import OrdinalEncoder

# %%
# Loading data
df_data = pd.read_csv("./data/train.csv")
df_data
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 2            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 3            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 4            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# ...          ...       ...  ...      ...    ...    ...         ...     ...
# 1455         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1456         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 1457         Lvl    AllPub  ...        0    NaN  GdPrv        Shed    2500
# 1458         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1459         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0         2   2008        WD         Normal     208500
# 1         5   2007        WD         Normal     181500
# 2         9   2008        WD         Normal     223500
# 3         2   2006        WD        Abnorml     140000
# 4        12   2008        WD         Normal     250000
# ...     ...    ...       ...            ...        ...
# 1455      8   2007        WD         Normal     175000
# 1456      2   2010        WD         Normal     210000
# 1457      5   2010        WD         Normal     266500
# 1458      4   2010        WD         Normal     142125
# 1459      6   2008        WD         Normal     147500
#
# [1460 rows x 81 columns]

# %%
# Some useful constants
target_feature = "SalePrice"
random_state = 0
test_size = 0.25
max_ohe_cardinality = 10  # Maximum unique values for one-hot encoding

# %%
# Some useful functions
def println(ch="-", n=30):
    print(ch * n)
 
def compute_rmse(y, y_pred):
    """Compute Root Mean Squared Error (RMSE)"""
    return np.sqrt(np.mean((y - y_pred) ** 2))

def extract_categorical_columns(df, k):
    """
    Extracts numeric and categorical columns from a DataFrame, and splits categorical columns into low and high cardinality based on a threshold k.
    
    Args:
        df (pd.DataFrame): Input dataframe.
        k (int): Threshold for maximum unique values to consider a column low cardinality.
    
    Returns:
        num_cols (Index): Numeric columns.
        low_cardi (Index): Categorical columns with fewer than k unique values.
        high_cardi (Index): Categorical columns with k or more unique values.
    """
    # Not including category type because the data is loaded from a csv and 
    # the columns are not set to category type by default.
    cat_cols = df.select_dtypes(exclude=["int64", "float64", "float32", "bool"]).columns
    num_cols = df.select_dtypes(include=["int64", "float64", "float32", "bool"]).columns

    low_cardi = [col for col in cat_cols if df[col].nunique() < k] 
    high_cardi = [col for col in cat_cols if df[col].nunique() >= k]
    return num_cols, low_cardi, high_cardi

    
def one_hot_encode(df):
    """
    One-hot encodes all columns in the given DataFrame using sklearn's OneHotEncoder.
    
    Args:
        df (pd.DataFrame): DataFrame containing only categorical columns to encode.
    
    Returns:
        pd.DataFrame: One-hot encoded DataFrame with new binary columns for each category.
    """
    # One-hot encode only low cardinality
    ohe = OneHotEncoder(sparse_output=False, drop="first")  # drop first to avoid dummy trap
    ohe_df = pd.DataFrame(
        ohe.fit_transform(df),
        columns=ohe.get_feature_names_out(df.columns),
        index=df.index
    )
    return ohe_df 
 
def show_values_summary(df):
    for col in df_low: 
        println()
        print(f"{col}: {df_data[col].nunique()} unique values") 
        println()
        print(df_data[col].value_counts())
        println(ch="_")
        
def print_title(title):
    println()
    print(title)
    println()

def ordinal_encode(df, ord_cat_maps):
    """
    Ordinally encodes specified columns in a DataFrame using provided category-to-integer mappings.
    
    Args:
        df (pd.DataFrame): DataFrame containing columns to encode.
        ord_cat_maps (dict): Dictionary mapping column names to their category-to-integer mappings.
    
    Returns:
        pd.DataFrame: DataFrame with ordinally encoded columns, prefixed with 'enc_'.
    """ 
    df_new = pd.DataFrame()
    cols = df.columns
    for col in cols:
        if col in ord_cat_maps:
            df_new["enc_" + col] = df[col].apply(lambda x: my_map(x, col, ord_cat_maps))

    return df_new

def my_map(x, col, ord_cat_maps):

    values = ord_cat_maps.get(col, -1)
    val = values.get(x, -1)  # Default to -1 if x is not in the mapping
    if pd.isna(x):
        val = -1
    return val

# %%
# Extracting target category
df_Y = pd.DataFrame()
if target_feature in df_data.columns:
    df_Y = df_data.pop(target_feature)


# Selecting Categorical columns from low cardinality categories
df_ord = df_data[ord_cols]
df_data_no_ord = df_data.drop(labels=ord_cols, axis=1, errors='ignore')


# Extracting numeric and categorical columns with low and high cardinality
num_cols, low_cols, hi_cols = extract_categorical_columns(df_data_no_ord, k=10)

# Ordinal Columns
ord_cols = [
    "LandSlope", "OverallQual", "OverallCond", "ExterQual", "ExterCond",
    "BsmtQual", "BsmtCond", "BsmtExposure", "BsmtFinType1", "BsmtFinType2",
    "HeatingQC", "KitchenQual", "FireplaceQu", "GarageQual", "GarageCond", "PoolQC"
]
subClassCol = "MSSubClass"
df_cat = df_data_no_ord.drop(labels=num_cols, axis=1, errors='ignore')
df_num = df_data[num_cols].drop(labels=["Id"], axis=1, errors='ignore')
df_cat[subClassCol] = df_num.pop(subClassCol)
df_hi_cat = df_cat[hi_cols]
df_low_cat = df_cat.drop(labels=hi_cols, axis=1, errors='ignore')
# One-hot encoding low cardinality categorical columns
df_low_cat = one_hot_encode(df_low_cat)


#df_low_cat

ord_cat_maps = { 
    "LandSlope": {"Gtl": 1, "Mod": 2, "Sev": 3},
    "ExterQual": {"Ex": 5, "Gd": 4, "TA": 3, "Fa": 2, "Po": 1},
    "ExterCond": {"Ex": 5, "Gd": 4, "TA": 3, "Fa": 2, "Po": 1},
    "BsmtQual": {"Ex": 10, "Gd": 9, "TA": 8, "Fa": 7, "Po": 3, "NA": 0},
    "BsmtCond": {"Ex": 5, "Gd": 4, "TA": 3, "Fa": 2, "Po": 1},
    "BsmtExposure": {"Gd": 5, "Av": 4, "Mn": 3, "No": 2, "NA": 0},
    "BsmtFinType1": {"GLQ": 6, "ALQ": 5, "BLQ": 4, "Rec": 3, "LwQ": 2, "Unf": 1, "NA": 0},
    "BsmtFinType2": {"GLQ": 6, "ALQ": 5, "BLQ": 4, "Rec": 3, "LwQ": 2, "Unf": 1, "NA": 0},
    "HeatingQC": {"Ex": 5, "Gd": 4, "TA": 3, "Fa": 2, "Po": 1},
    "FireplaceQu": {"Ex": 10, "Gd": 9, "TA": 8, "Fa": 7, "Po": 3, "NA": 0},
    "GarageQual": {"Ex": 10, "Gd": 9, "TA": 8, "Fa": 7, "Po": 3, "NA": 0},
    "GarageCond": {"Ex": 10, "Gd": 9, "TA": 8, "Fa": 7, "Po": 3, "NA": 0},
    "PoolQC": {"Ex": 10, "Gd": 9, "TA": 8, "Fa": 7, "Po": 3, "NA": 0},
}

df_ord_cat = ordinal_encode(df_ord, ord_cat_maps)
df_ord_cat

#print_title("Ordinal Values")
# print(df_ord.head(5))
# for col in ord_cols:
#     print(f"{col}: {df_ord[col].nunique()} unique values")
#     print(df_ord[col].value_counts().sort_values())
#     println(ch="_")
#print(ord_cols)

#print_title("Categorical Values")
# print(df_cat.head(5))
# print_title("Numeric columns")
# print(df_num.head(5))
# Out:
# col in map: LandSlope
# col in map: ExterQual
# col in map: ExterCond
# col in map: BsmtQual
# col in map: BsmtCond
# col in map: BsmtExposure
# col in map: BsmtFinType1
# col in map: BsmtFinType2
# col in map: HeatingQC
# col in map: FireplaceQu
# col in map: GarageQual
# col in map: GarageCond
# col in map: PoolQC
#       enc_LandSlope  enc_ExterQual  enc_ExterCond  enc_BsmtQual  enc_BsmtCond  \
# 0                 1              4              3             9             3
# 1                 1              3              3             9             3
# 2                 1              4              3             9             3
# 3                 1              3              3             8             4
# 4                 1              4              3             9             3
# ...             ...            ...            ...           ...           ...
# 1455              1              3              3             9             3
# 1456              1              3              3             9             3
# 1457              1              5              4             8             4
# 1458              1              3              3             8             3
# 1459              1              4              3             8             3
#
#       enc_BsmtExposure  enc_BsmtFinType1  enc_BsmtFinType2  enc_HeatingQC  \
# 0                    2                 6                 1              5
# 1                    5                 5                 1              5
# 2                    3                 6                 1              5
# 3                    2                 5                 1              4
# 4                    4                 6                 1              5
# ...                ...               ...               ...            ...
# 1455                 2                 1                 1              5
# 1456                 2                 5                 3              3
# 1457                 2                 6                 1              5
# 1458                 3                 6                 3              4
# 1459                 2                 4                 2              4
#
#       enc_FireplaceQu  enc_GarageQual  enc_GarageCond  enc_PoolQC
# 0                  -1               8               8          -1
# 1                   8               8               8          -1
# 2                   8               8               8          -1
# 3                   9               8               8          -1
# 4                   8               8               8          -1
# ...               ...             ...             ...         ...
# 1455                8               8               8          -1
# 1456                8               8               8          -1
# 1457                9               8               8          -1
# 1458               -1               8               8          -1
# 1459               -1               8               8          -1
#
# [1460 rows x 13 columns]

# %%
# Before starting the analysis, let's setup a baseline performance
dummy_model = DummyRegressor()
X_dummy = df_data.copy()
y_dummy = X_dummy.pop(target_feature)
X_dummy_train, y_dummy_train, X_dummy_test, y_dummy_test = train_test_split(X_dummy, y_dummy, test_size=test_size, random_state=random_state)
dummy_model.fit(X_dummy_train, y_dummy_train)
y_dummy_pred = dummy_model.predict(X_dummy)
dummy_scores_train = compute_rmse(y_dummy, y_dummy_pred)

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %%
#df_data.info()
null_columns = df_data.columns[df_data.isna().any()]
print("Columns with null values:", null_columns.tolist())

df_data.describe(include="all")
# Out:
# Columns with null values: ['LotFrontage', 'Alley', 'MasVnrType', 'MasVnrArea', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Electrical', 'FireplaceQu', 'GarageType', 'GarageYrBlt', 'GarageFinish', 'GarageQual', 'GarageCond', 'PoolQC', 'Fence', 'MiscFeature']
#                  Id   MSSubClass MSZoning  LotFrontage        LotArea Street  \
# count   1460.000000  1460.000000     1460  1201.000000    1460.000000   1460
# unique          NaN          NaN        5          NaN            NaN      2
# top             NaN          NaN       RL          NaN            NaN   Pave
# freq            NaN          NaN     1151          NaN            NaN   1454
# mean     730.500000    56.897260      NaN    70.049958   10516.828082    NaN
# std      421.610009    42.300571      NaN    24.284752    9981.264932    NaN
# min        1.000000    20.000000      NaN    21.000000    1300.000000    NaN
# 25%      365.750000    20.000000      NaN    59.000000    7553.500000    NaN
# 50%      730.500000    50.000000      NaN    69.000000    9478.500000    NaN
# 75%     1095.250000    70.000000      NaN    80.000000   11601.500000    NaN
# max     1460.000000   190.000000      NaN   313.000000  215245.000000    NaN
#
#        Alley LotShape LandContour Utilities  ...     PoolArea PoolQC  Fence  \
# count     91     1460        1460      1460  ...  1460.000000      7    281
# unique     2        4           4         2  ...          NaN      3      4
# top     Grvl      Reg         Lvl    AllPub  ...          NaN     Gd  MnPrv
# freq      50      925        1311      1459  ...          NaN      3    157
# mean     NaN      NaN         NaN       NaN  ...     2.758904    NaN    NaN
# std      NaN      NaN         NaN       NaN  ...    40.177307    NaN    NaN
# min      NaN      NaN         NaN       NaN  ...     0.000000    NaN    NaN
# 25%      NaN      NaN         NaN       NaN  ...     0.000000    NaN    NaN
# 50%      NaN      NaN         NaN       NaN  ...     0.000000    NaN    NaN
# 75%      NaN      NaN         NaN       NaN  ...     0.000000    NaN    NaN
# max      NaN      NaN         NaN       NaN  ...   738.000000    NaN    NaN
#
#        MiscFeature       MiscVal       MoSold       YrSold  SaleType  \
# count           54   1460.000000  1460.000000  1460.000000      1460
# unique           4           NaN          NaN          NaN         9
# top           Shed           NaN          NaN          NaN        WD
# freq            49           NaN          NaN          NaN      1267
# mean           NaN     43.489041     6.321918  2007.815753       NaN
# std            NaN    496.123024     2.703626     1.328095       NaN
# min            NaN      0.000000     1.000000  2006.000000       NaN
# 25%            NaN      0.000000     5.000000  2007.000000       NaN
# 50%            NaN      0.000000     6.000000  2008.000000       NaN
# 75%            NaN      0.000000     8.000000  2009.000000       NaN
# max            NaN  15500.000000    12.000000  2010.000000       NaN
#
#         SaleCondition      SalePrice
# count            1460    1460.000000
# unique              6            NaN
# top            Normal            NaN
# freq             1198            NaN
# mean              NaN  180921.195890
# std               NaN   79442.502883
# min               NaN   34900.000000
# 25%               NaN  129975.000000
# 50%               NaN  163000.000000
# 75%               NaN  214000.000000
# max               NaN  755000.000000
#
# [11 rows x 81 columns]

# %%
# Correlation between featues. It is intended to spot redundant features
plt.figure(figsize=(12, 6))
sns.heatmap(df_data.corr(numeric_only=True), cmap="coolwarm", annot=False)
# Out:
# <Axes: >

# %%
df_data.corr(numeric_only=True).loc["LotArea"] # Get pairs of features with correlation > 0.8 and not the same feature
# Out:
# Id              -0.033226
# MSSubClass      -0.139781
# LotFrontage      0.426095
# LotArea          1.000000
# OverallQual      0.105806
# OverallCond     -0.005636
# YearBuilt        0.014228
# YearRemodAdd     0.013788
# MasVnrArea       0.104160
# BsmtFinSF1       0.214103
# BsmtFinSF2       0.111170
# BsmtUnfSF       -0.002618
# TotalBsmtSF      0.260833
# 1stFlrSF         0.299475
# 2ndFlrSF         0.050986
# LowQualFinSF     0.004779
# GrLivArea        0.263116
# BsmtFullBath     0.158155
# BsmtHalfBath     0.048046
# FullBath         0.126031
# HalfBath         0.014259
# BedroomAbvGr     0.119690
# KitchenAbvGr    -0.017784
# TotRmsAbvGrd     0.190015
# Fireplaces       0.271364
# GarageYrBlt     -0.024947
# GarageCars       0.154871
# GarageArea       0.180403
# WoodDeckSF       0.171698
# OpenPorchSF      0.084774
# EnclosedPorch   -0.018340
# 3SsnPorch        0.020423
# ScreenPorch      0.043160
# PoolArea         0.077672
# MiscVal          0.038068
# MoSold           0.001205
# YrSold          -0.014261
# SalePrice        0.263843
# Name: LotArea, dtype: float64

# %%
# Correlation between features and target. Here we are trying to know which features are releant to predict the target variable
# Correlation near 0 could mean that the feature is not relevant to predict the target variable or that it has a non linear relationship with it 

corr_matrix = df_data.corr(numeric_only=True)
high_corr = np.where((corr_matrix > 0.7) & (corr_matrix < 1.0))

high_corr_pairs = [(corr_matrix.index[row], corr_matrix.columns[col], corr_matrix.iloc[row, col])
                  for row, col in zip(*high_corr) if corr_matrix.index[row] != corr_matrix.columns[col]]

print("Highly correlated feature pairs (corr > 0.8):")
for feat1, feat2, corr_val in high_corr_pairs:
    print(f"{feat1} - {feat2}: {corr_val:.2f}")
# Out:
# Highly correlated feature pairs (corr > 0.8):
# OverallQual - SalePrice: 0.79
# YearBuilt - GarageYrBlt: 0.83
# TotalBsmtSF - 1stFlrSF: 0.82
# 1stFlrSF - TotalBsmtSF: 0.82
# GrLivArea - TotRmsAbvGrd: 0.83
# GrLivArea - SalePrice: 0.71
# TotRmsAbvGrd - GrLivArea: 0.83
# GarageYrBlt - YearBuilt: 0.83
# GarageCars - GarageArea: 0.88
# GarageArea - GarageCars: 0.88
# SalePrice - OverallQual: 0.79
# SalePrice - GrLivArea: 0.71

# %% [markdown]
# **From the output above, we can see that some candidates for removal are:**
# - GarageYrBlt
# - 1sFlrSF
# - TotRmsAbvGrd
# - GarageCars

# %%
# Selecting columns
# Remove LotFrontage -> has a big correlation with LotArea
# Remove 
columuns = ["MSSubClass", "MSZoning", "LotArea", "Street", "LotShape", "LandContour", "Utilities", "LotConfig", "LandSlope", "Neighborhood", "BldgType", "HouseStyle", "OverallQual", 
            "OverallCond", "YearBuilt", "RoofStyle", "RoofMatl"]

# %%
A = np.random.randn(4,3)

B = np.sum(A, axis = 1, keepdims = True) 
B
B.shape
# Out:
# (4, 1)
